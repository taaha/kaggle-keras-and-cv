# %% [markdown]
# **This notebook is an exercise in the [Computer Vision](https://www.kaggle.com/learn/computer-vision) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/custom-convnets).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In these exercises, you'll build a custom convnet with performance competitive to the VGG16 model from Lesson 1.
#
# Get started by running the code cell below.

# %%
# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.computer_vision.ex5 import *

# Imports
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Reproducability
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
warnings.filterwarnings("ignore") # to clean up output cells


# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    '../input/car-or-truck/train',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    '../input/car-or-truck/valid',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)

# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# Found 5117 files belonging to 2 classes.
# 2022-12-13 11:47:58.684294: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-13 11:47:58.780643: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-13 11:47:58.781492: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-13 11:47:58.787659: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-13 11:47:58.787970: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-13 11:47:58.788990: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-13 11:47:58.789989: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-13 11:48:01.127674: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-13 11:48:01.128500: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-13 11:48:01.129248: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-13 11:48:01.129850: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 5051 files belonging to 2 classes.

# %% [markdown]
# # Design a Convnet #
#
# Let's design a convolutional network with a block architecture like we saw in the tutorial. The model from the example had three blocks, each with a single convolutional layer. Its performance on the "Car or Truck" problem was okay, but far from what the pretrained VGG16 could achieve. It might be that our simple network lacks the ability to extract sufficiently complex features. We could try improving the model either by adding more blocks or by adding convolutions to the blocks we have.
#
# Let's go with the second approach. We'll keep the three block structure, but increase the number of `Conv2D` layer in the second block to two, and in the third block to three.
#
# <figure>
# <!-- <img src="./images/2-convmodel-2.png" width="250" alt="Diagram of a convolutional model."> -->
# <img src="https://i.imgur.com/Vko6nCK.png" width="250" alt="Diagram of a convolutional model.">
# </figure>
#
# # 1) Define Model #
#
# Given the diagram above, complete the model by defining the layers of the third block.

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    # Block One
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
                  input_shape=[128, 128, 3]),
    layers.MaxPool2D(),

    # Block Two
    layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Block Three
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),
    # YOUR CODE HERE
    # ____,

    # Head
    layers.Flatten(),
    layers.Dense(6, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_1.hint()
#q_1.solution()

# %% [markdown]
# # 2) Compile #
#
# To prepare for training, compile the model with an appropriate loss and accuracy metric for the "Car or Truck" dataset.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['binary_accuracy']
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)
q_2.assert_check_passed()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, let's test the performance of this new model. First run this cell to fit the model to the training set.

# %%
history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=50,
)
# Out:
# 2022-12-13 11:49:46.609245: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2022-12-13 11:49:49.681045: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 80/80 [==============================] - 40s 395ms/step - loss: 0.6799 - binary_accuracy: 0.5742 - val_loss: 0.6657 - val_binary_accuracy: 0.5785
# Epoch 2/50
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6640 - binary_accuracy: 0.5787 - val_loss: 0.6562 - val_binary_accuracy: 0.5785
# Epoch 3/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.6604 - binary_accuracy: 0.5787 - val_loss: 0.6498 - val_binary_accuracy: 0.5787
# Epoch 4/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.6519 - binary_accuracy: 0.5894 - val_loss: 0.6416 - val_binary_accuracy: 0.6068
# Epoch 5/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.6451 - binary_accuracy: 0.6242 - val_loss: 0.6362 - val_binary_accuracy: 0.5977
# Epoch 6/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.6335 - binary_accuracy: 0.6439 - val_loss: 0.6304 - val_binary_accuracy: 0.6171
# Epoch 7/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.6285 - binary_accuracy: 0.6459 - val_loss: 0.6232 - val_binary_accuracy: 0.6260
# Epoch 8/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.6185 - binary_accuracy: 0.6707 - val_loss: 0.6152 - val_binary_accuracy: 0.6723
# Epoch 9/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.6137 - binary_accuracy: 0.6793 - val_loss: 0.6045 - val_binary_accuracy: 0.6686
# Epoch 10/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.6001 - binary_accuracy: 0.6949 - val_loss: 0.5900 - val_binary_accuracy: 0.6830
# Epoch 11/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.5763 - binary_accuracy: 0.7071 - val_loss: 0.5598 - val_binary_accuracy: 0.7149
# Epoch 12/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.5475 - binary_accuracy: 0.7315 - val_loss: 0.5418 - val_binary_accuracy: 0.7288
# Epoch 13/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.5269 - binary_accuracy: 0.7409 - val_loss: 0.5218 - val_binary_accuracy: 0.7391
# Epoch 14/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.5005 - binary_accuracy: 0.7631 - val_loss: 0.5105 - val_binary_accuracy: 0.7523
# Epoch 15/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.4737 - binary_accuracy: 0.7794 - val_loss: 0.4938 - val_binary_accuracy: 0.7694
# Epoch 16/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.4542 - binary_accuracy: 0.7846 - val_loss: 0.4640 - val_binary_accuracy: 0.7830
# Epoch 17/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.4241 - binary_accuracy: 0.8089 - val_loss: 0.4634 - val_binary_accuracy: 0.7925
# Epoch 18/50
# 80/80 [==============================] - 3s 43ms/step - loss: 0.3949 - binary_accuracy: 0.8300 - val_loss: 0.4727 - val_binary_accuracy: 0.7878
# Epoch 19/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.3819 - binary_accuracy: 0.8302 - val_loss: 0.4471 - val_binary_accuracy: 0.8064
# Epoch 20/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.3586 - binary_accuracy: 0.8440 - val_loss: 0.4799 - val_binary_accuracy: 0.7935
# Epoch 21/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.3359 - binary_accuracy: 0.8554 - val_loss: 0.4145 - val_binary_accuracy: 0.8206
# Epoch 22/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.3242 - binary_accuracy: 0.8581 - val_loss: 0.4188 - val_binary_accuracy: 0.8072
# Epoch 23/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.3092 - binary_accuracy: 0.8679 - val_loss: 0.4191 - val_binary_accuracy: 0.8280
# Epoch 24/50
# 80/80 [==============================] - 3s 43ms/step - loss: 0.2785 - binary_accuracy: 0.8820 - val_loss: 0.4323 - val_binary_accuracy: 0.8167
# Epoch 25/50
# 80/80 [==============================] - 3s 43ms/step - loss: 0.2658 - binary_accuracy: 0.8884 - val_loss: 0.4693 - val_binary_accuracy: 0.8068
# Epoch 26/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.2584 - binary_accuracy: 0.8923 - val_loss: 0.5644 - val_binary_accuracy: 0.7771
# Epoch 27/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.2561 - binary_accuracy: 0.8949 - val_loss: 0.4989 - val_binary_accuracy: 0.8018
# Epoch 28/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.2365 - binary_accuracy: 0.9021 - val_loss: 0.4993 - val_binary_accuracy: 0.8137
# Epoch 29/50
# 80/80 [==============================] - 3s 43ms/step - loss: 0.2342 - binary_accuracy: 0.9027 - val_loss: 0.4152 - val_binary_accuracy: 0.8264
# Epoch 30/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.2075 - binary_accuracy: 0.9183 - val_loss: 0.3972 - val_binary_accuracy: 0.8400
# Epoch 31/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.1898 - binary_accuracy: 0.9216 - val_loss: 0.4400 - val_binary_accuracy: 0.8493
# Epoch 32/50
# 80/80 [==============================] - 3s 43ms/step - loss: 0.1564 - binary_accuracy: 0.9384 - val_loss: 0.4991 - val_binary_accuracy: 0.8428
# Epoch 33/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.1369 - binary_accuracy: 0.9476 - val_loss: 0.5191 - val_binary_accuracy: 0.8412
# Epoch 34/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.1409 - binary_accuracy: 0.9435 - val_loss: 0.5062 - val_binary_accuracy: 0.8386
# Epoch 35/50
# 80/80 [==============================] - 3s 43ms/step - loss: 0.1298 - binary_accuracy: 0.9506 - val_loss: 0.6758 - val_binary_accuracy: 0.8105
# Epoch 36/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.1463 - binary_accuracy: 0.9382 - val_loss: 0.5965 - val_binary_accuracy: 0.8363
# Epoch 37/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.1170 - binary_accuracy: 0.9558 - val_loss: 0.6042 - val_binary_accuracy: 0.8398
# Epoch 38/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.1037 - binary_accuracy: 0.9590 - val_loss: 0.6730 - val_binary_accuracy: 0.8379
# Epoch 39/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0968 - binary_accuracy: 0.9662 - val_loss: 0.6696 - val_binary_accuracy: 0.8353
# Epoch 40/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.1083 - binary_accuracy: 0.9603 - val_loss: 0.6288 - val_binary_accuracy: 0.8436
# Epoch 41/50
# 80/80 [==============================] - 3s 43ms/step - loss: 0.0926 - binary_accuracy: 0.9633 - val_loss: 0.5596 - val_binary_accuracy: 0.8432
# Epoch 42/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0879 - binary_accuracy: 0.9631 - val_loss: 0.6527 - val_binary_accuracy: 0.8438
# Epoch 43/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0744 - binary_accuracy: 0.9711 - val_loss: 0.5827 - val_binary_accuracy: 0.8533
# Epoch 44/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0824 - binary_accuracy: 0.9699 - val_loss: 0.5779 - val_binary_accuracy: 0.8531
# Epoch 45/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0849 - binary_accuracy: 0.9650 - val_loss: 0.6106 - val_binary_accuracy: 0.8533
# Epoch 46/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0688 - binary_accuracy: 0.9722 - val_loss: 0.5791 - val_binary_accuracy: 0.8531
# Epoch 47/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0719 - binary_accuracy: 0.9713 - val_loss: 0.6470 - val_binary_accuracy: 0.8497
# Epoch 48/50
# 80/80 [==============================] - 3s 43ms/step - loss: 0.0608 - binary_accuracy: 0.9801 - val_loss: 0.6596 - val_binary_accuracy: 0.8349
# Epoch 49/50
# 80/80 [==============================] - 3s 43ms/step - loss: 0.0595 - binary_accuracy: 0.9767 - val_loss: 0.5967 - val_binary_accuracy: 0.8309
# Epoch 50/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0580 - binary_accuracy: 0.9797 - val_loss: 0.6639 - val_binary_accuracy: 0.8406

# %% [markdown]
# And now run the cell below to plot the loss and metric curves for this training run.

# %%
import pandas as pd
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();

# %% [markdown]
# # 3) Train the Model #
#
# How would you interpret these training curves? Did this model improve upon the model from the tutorial?

# %%
# View the solution (Run this code cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
#
# The learning curves for the model from the tutorial diverged fairly rapidly. This would indicate that it was prone to overfitting and in need of some regularization. The additional layer in our new model would make it even more prone to overfitting. However, adding some regularization with the `Dropout` layer helped prevent this. These changes improved the validation accuracy of the model by several points.

# %% [markdown]
# # Conclusion #
#
# These exercises showed you how to design a custom convolutional network to solve a specific classification problem. Though most models these days will be built on top of a pretrained base, it certain circumstances a smaller custom convnet might still be preferable -- such as with a smaller or unusual dataset or when computing resources are very limited. As you saw here, for certain problems they can perform just as well as a pretrained model.
#
# # Keep Going #
#
# Continue on to [**Lesson 6**](https://www.kaggle.com/ryanholbrook/data-augmentation), where you'll learn a widely-used technique that can give a boost to your training data: **data augmentation**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/computer-vision/discussion) to chat with other learners.*
